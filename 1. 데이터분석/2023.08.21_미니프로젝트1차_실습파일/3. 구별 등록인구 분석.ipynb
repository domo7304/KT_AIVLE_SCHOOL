# %% [markdown]
# ## AIVLE School [AI 미니프로젝트] '서울시 생활정보 기반 대중교통 수요 분석'<br>

# %% [markdown]
# # 3. 구 별 등록인구 분석
# ### 서울시 내 각 구 별로 등록된 인구를 분석합니다.

# %% [markdown]
# ## 데이터 안내
#
# [데이터 파일명]
# * 3. seoul_people.csv
#
# [데이터 정보]
# * 서울시 주민등록 데이터
#
# [데이터 컬럼 정보]
# * 한국인, 등록 외국인, 합계, 세대수, 고령인구수

# %% [markdown]
# # 3.1.데이터 불러오기

# %% [markdown]
# #### [3.1.1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 '3. seoul_people.csv'파일을 'seoul_people' 변수에 저장하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 '\t' 입니다
#         * 인코더를 사용해 주세요
#     * 데이터를 불러올 때 오류가 발생한다면, 오류에 대해 직접 검색하여 해결해보세요.

# %%
import pandas as pd
import numpy as np

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_people = pd.read_csv('./3. seoul_people.csv', sep='\t', encoding='cp949')

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_people.shape
# Out:
# (28, 14)

# %% [markdown]
# # 3.2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [3.2.1] 기본 정보 확인하기
# * 'seoul_people' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head', 'tail' 등 전부 활용해 보세요.

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_people.describe()
# Out:
#               기간  자치구  세대  인구 인구.1 인구.2 인구.3 인구.4 인구.5   인구.6   인구.7   인구.8  \
# count         28   28  28  28   28   28   28   28   28     28     28     28
# unique         2   27  27  28   28   28   28   28   28     28     28     28
# top     2022.1/4  자치구  세대  합계   합계   합계  한국인  한국인  한국인  등록외국인  등록외국인  등록외국인
# freq          26    2   2   1    1    1    1    1    1      1      1      1
#
#         세대당인구  65세이상고령자
# count      28        28
# unique     24        27
# top     세대당인구  65세이상고령자
# freq        2         2

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        28 non-null     object
#  1   자치구       28 non-null     object
#  2   세대        28 non-null     object
#  3   인구        28 non-null     object
#  4   인구.1      28 non-null     object
#  5   인구.2      28 non-null     object
#  6   인구.3      28 non-null     object
#  7   인구.4      28 non-null     object
#  8   인구.5      28 non-null     object
#  9   인구.6      28 non-null     object
#  10  인구.7      28 non-null     object
#  11  인구.8      28 non-null     object
#  12  세대당인구     28 non-null     object
#  13  65세이상고령자  28 non-null     object
# dtypes: object(14)
# memory usage: 3.2+ KB

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_people.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대       합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대        계       남자       여자        계       남자
# 2  2022.1/4   합계  4451444  9732617  4716704  5015913  9506778  4613910
# 3  2022.1/4  종로구    73766   153684    74018    79666   144275    69911
# 4  2022.1/4   중구    63767   131450    63869    67581   122173    59448
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  4892868  225839  102794  123045   2.14   1628980
# 3    74364    9409    4107    5302   1.96     28064
# 4    62725    9277    4421    4856   1.92     24742

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_people.tail()
# Out:
#           기간  자치구      세대      인구    인구.1    인구.2    인구.3    인구.4    인구.5  \
# 23  2022.1/4  관악구  279353  500336  250450  249886  486375  244409  241966
# 24  2022.1/4  서초구  169895  413677  197665  216012  409823  195806  214017
# 25  2022.1/4  강남구  234612  537338  257096  280242  532577  254866  277711
# 26  2022.1/4  송파구  285106  668261  321963  346298  662607  319407  343200
# 27  2022.1/4  강동구  201926  465097  227891  237206  461300  226203  235097
#
#      인구.6  인구.7  인구.8 세대당인구 65세이상고령자
# 23  13961  6041  7920  1.74    80686
# 24   3854  1859  1995  2.41    61404
# 25   4761  2230  2531  2.27    79575
# 26   5654  2556  3098  2.32    99854
# 27   3797  1688  2109  2.28    75477

# %% [markdown]
# #### [3.2.2] 원하는 데이터 형태로 저장하기
#
# * head, tail 등을 살펴본 결과를 토대로 header 값을 적절히 지정하여 데이터를 다시 불러오고 필요한 컬럼만 저장하세요

# %%
#read_csv 재실행. 단, header값을 적절히 지정
seoul_people = pd.read_csv('./3. seoul_people.csv', sep='\t', encoding='cp949', header=3)

# %%
seoul_people.columns = ['기간', '자치구', '세대', '총합', '남자 총합', '여자 총합', '한국인 총합', '한국인 남자 총합',  '한국인 여자 총합', '외국인 총합', '외국인 남자 총합', '외국인 여자 총합', '세대당 인구', '65세 이상 고령자']

# %%
seoul_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기간          25 non-null     object
#  1   자치구         25 non-null     object
#  2   세대          25 non-null     int64
#  3   총합          25 non-null     int64
#  4   남자 총합       25 non-null     int64
#  5   여자 총합       25 non-null     int64
#  6   한국인 총합      25 non-null     int64
#  7   한국인 남자 총합   25 non-null     int64
#  8   한국인 여자 총합   25 non-null     int64
#  9   외국인 총합      25 non-null     int64
#  10  외국인 남자 총합   25 non-null     int64
#  11  외국인 여자 총합   25 non-null     int64
#  12  세대당 인구      25 non-null     float64
#  13  65세 이상 고령자  25 non-null     int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 2.9+ KB

# %%
seoul_people.head()
# Out:
#          기간  자치구      세대      총합   남자 총합   여자 총합  한국인 총합  한국인 남자 총합  \
# 0  2022.1/4  종로구   73766  153684   74018   79666  144275      69911
# 1  2022.1/4   중구   63767  131450   63869   67581  122173      59448
# 2  2022.1/4  용산구  111207  236518  114571  121947  222169     106735
# 3  2022.1/4  성동구  134533  291609  141662  149947  285073     138847
# 4  2022.1/4  광진구  169483  353110  169525  183585  340707     164346
#
#    한국인 여자 총합  외국인 총합  외국인 남자 총합  외국인 여자 총합  세대당 인구  65세 이상 고령자
# 0      74364    9409       4107       5302    1.96       28064
# 1      62725    9277       4421       4856    1.92       24742
# 2     115434   14349       7836       6513    2.00       39461
# 3     146226    6536       2815       3721    2.12       46896
# 4     176361   12403       5179       7224    2.01       52604

# %%
seoul_people.tail()
# Out:
#           기간  자치구      세대      총합   남자 총합   여자 총합  한국인 총합  한국인 남자 총합  \
# 20  2022.1/4  관악구  279353  500336  250450  249886  486375     244409
# 21  2022.1/4  서초구  169895  413677  197665  216012  409823     195806
# 22  2022.1/4  강남구  234612  537338  257096  280242  532577     254866
# 23  2022.1/4  송파구  285106  668261  321963  346298  662607     319407
# 24  2022.1/4  강동구  201926  465097  227891  237206  461300     226203
#
#     한국인 여자 총합  외국인 총합  외국인 남자 총합  외국인 여자 총합  세대당 인구  65세 이상 고령자
# 20     241966   13961       6041       7920    1.74       80686
# 21     214017    3854       1859       1995    2.41       61404
# 22     277711    4761       2230       2531    2.27       79575
# 23     343200    5654       2556       3098    2.32       99854
# 24     235097    3797       1688       2109    2.28       75477

# %%
# 다시 불러온 데이터프레임에서 여러분 각자가 사용하고자 하는 컬럼만 가져오세요.
seoul_people = seoul_people[['자치구', '총합', '남자 총합', '여자 총합', '65세 이상 고령자']]

# %%
seoul_people = seoul_people[1:]

# %%
seoul_people
# Out:
#      자치구      총합   남자 총합   여자 총합  65세 이상 고령자
# 1     중구  131450   63869   67581       24742
# 2    용산구  236518  114571  121947       39461
# 3    성동구  291609  141662  149947       46896
# 4    광진구  353110  169525  183585       52604
# 5   동대문구  352592  172318  180274       62963
# 6    중랑구  393600  193623  199977       72851
# 7    성북구  442680  212277  230403       75719
# 8    강북구  300824  145934  154890       64961
# 9    도봉구  318100  154440  163660       65122
# 10   노원구  514445  247417  267028       89426
# 11   은평구  476013  227172  248841       88418
# 12  서대문구  317075  149805  167270       55012
# 13   마포구  378629  176886  201743       55168
# 14   양천구  449378  219882  229496       69953
# 15   강서구  578426  277797  300629       93924
# 16   구로구  419984  208027  211957       73864
# 17   금천구  244901  123959  120942       41819
# 18  영등포구  400241  198080  202161       63547
# 19   동작구  394649  190377  204272       67470
# 20   관악구  500336  250450  249886       80686
# 21   서초구  413677  197665  216012       61404
# 22   강남구  537338  257096  280242       79575
# 23   송파구  668261  321963  346298       99854
# 24   강동구  465097  227891  237206       75477

# %%
# 해당 데이터프레임을 csv 파일로 저장하세요.
seoul_people.to_csv('df_seoul_people.csv')

# %% [markdown]
# # 3.3.데이터 분석하기
# + 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별하세요.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [3.3.1] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ---
